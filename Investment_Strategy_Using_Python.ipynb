# %% [markdown]
# <a href="https://colab.research.google.com/github/FaizanFarooq3/Financial-Analytics-with-Python/blob/main/Investment_Strategy_Using_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Investment Strategy Using Python**
# Here, we assume that the individual retires in 10 years and the expenses of that individual is fixed. There is a saying that "If you invest 50% of your income for 10 years then after 10 years you will be able to support yourself."
#
# ### Importing the necessary libraries

# %%
import numpy as np
import pandas as pd
import  matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Lets create lists for the various features

Year = []
Yearly_Income = []
Yearly_Expenses = []
Yearly_Investments = []
Annual_Returns = []

# %%
# Lets consider a fixed income per year($)
income = 35000

# Yearly constant expense
expense = income/2

# Average interest of 8% per year
interest_rate = 0.08

# Lets assume the individual invests half of his/her income
investment = income/2

# Calculating the annual return
annual_return = investment * interest_rate

# Getting the current year
year = 2024

# %%
# Appending the first values to our lists

Year.append(year)
Yearly_Income.append(income)
Yearly_Expenses.append(expense)
Yearly_Investments.append(investment)
Annual_Returns.append(annual_return)

# %%
# Looping for "n" years

invested_years = 20
for i in range(0, invested_years-1):
  # Update the investment to be the previous investment + previous annual returns + half of the income
  investment = investment + annual_return + income/2

  # Update the annual return to be the current investment times interest
  annual_return = investment * interest_rate

  # Appending the new data to the list
  Year.append(year+i+1)
  Yearly_Income.append(income)
  Yearly_Expenses.append(expense)
  Yearly_Investments.append(investment)
  Annual_Returns.append(annual_return)

# %%
# lets create a DataFrame

df = pd.DataFrame()
df["Year"] = Year
df["Yearly_Income"] = Yearly_Income
df["Yearly_Expenses"] = Yearly_Expenses
df["Yearly_Investments"] = Yearly_Investments
df["Annual_Returns"] = Annual_Returns

# Lets check the data
df
# Out:
#     Year  Yearly_Income  Yearly_Expenses  Yearly_Investments  Annual_Returns
# 0   2024          35000          17500.0        17500.000000     1400.000000
# 1   2025          35000          17500.0        36400.000000     2912.000000
# 2   2026          35000          17500.0        56812.000000     4544.960000
# 3   2027          35000          17500.0        78856.960000     6308.556800
# 4   2028          35000          17500.0       102665.516800     8213.241344
# 5   2029          35000          17500.0       128378.758144    10270.300652
# 6   2030          35000          17500.0       156149.058796    12491.924704
# 7   2031          35000          17500.0       186140.983499    14891.278680
# 8   2032          35000          17500.0       218532.262179    17482.580974
# 9   2033          35000          17500.0       253514.843153    20281.187452
# 10  2034          35000          17500.0       291296.030606    23303.682448
# 11  2035          35000          17500.0       332099.713054    26567.977044
# 12  2036          35000          17500.0       376167.690098    30093.415208
# 13  2037          35000          17500.0       423761.105306    33900.888425
# 14  2038          35000          17500.0       475161.993731    38012.959498
# 15  2039          35000          17500.0       530674.953229    42453.996258
# 16  2040          35000          17500.0       590628.949488    47250.315959
# 17  2041          35000          17500.0       655379.265447    52430.341236
# 18  2042          35000          17500.0       725309.606682    58024.768535
# 19  2043          35000          17500.0       800834.375217    64066.750017

# %%
# Lets visualize the data

plt.figure(figsize = (12.2,4.5))
plt.plot(df["Year"], df["Yearly_Expenses"], label = "Yearly_Expenses")
plt.plot(df["Year"], df["Annual_Returns"], label = "Annual_Returns")
plt.xticks(rotation = 45)
plt.title("Retire in 10 Years")
plt.xlabel("Years")
plt.ylabel("$")
plt.xticks(df["Year"])
plt.legend()
plt.show();

# %% [markdown]
# We can see that by 2033 the indvidual will be financially sustained.

# %%
# Lets see the rows where the individual can live off of returns

df[df["Yearly_Expenses"] <= df["Annual_Returns"]].head()
# Out:
#     Year  Yearly_Income  Yearly_Expenses  Yearly_Investments  Annual_Returns
# 9   2033          35000          17500.0       253514.843153    20281.187452
# 10  2034          35000          17500.0       291296.030606    23303.682448
# 11  2035          35000          17500.0       332099.713054    26567.977044
# 12  2036          35000          17500.0       376167.690098    30093.415208
# 13  2037          35000          17500.0       423761.105306    33900.888425
